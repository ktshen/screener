# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import numba as nb
import pandas_ta as ta
import os
import datetime
import json
from tabulate import tabulate
import sys
sys.path.append('../..')
import vectorbtpro as vbt
from vectorbtpro.portfolio.enums import SizeType
from src.utils import fu
from src.utils import plot_return_mdd
from src.strategy.BackTester import BackTester
from src.strategy.Analyzer import Analyzer
from src.strategy.MultiTester import MultiTester
from src.utils import plot_return_mdd,twinx_plot # as utils
from bband import get_data,Strategy

# %% [markdown]
# ### 樣本內全參數 (多、空)

# %%
import ast
import pandas as pd
import hiplot as hip

def insample_params_highland(coin:str, freq: str, direction: str):
    params_df = pd.read_csv(f'opt/{freq}/{coin}/{direction}_record_df.csv').drop(columns=['Unnamed: 0'])
    params_df['params'] = params_df['params'].apply(ast.literal_eval)
    temp_df = params_df['params'].apply(pd.Series)
    df = pd.concat([params_df.drop(columns='params'), temp_df], axis=1)
    target = df[['window_l_k','window_l_d','window_s_k','window_s_d','Sharpe Ratio','Calmar Ratio','Win Rate [%]']]
    data_for_hiplot = target.to_dict(orient='records')
    exp = hip.Experiment.from_iterable(data_for_hiplot)
    exp.display(force_full_width=False, width=400, height=100)

# %%
symbol_list = ['ETH','BTC','BNB','SOL','MATIC',
               'XRP','DYDX','AVAX','LINK','GAS',
               'DOGE','ORDI','TRB','WLD','ADA',
               'OP','FIL','ZRX','LTC','RUNE','ATOM',
               'ARB','GMT','ETC','ARK','BCH','DOT',
               '1000PEPE','LDO','SUI','GALA','CAKE',
               'APE','INJ','FTM','APT','YFI','OMG',
               'SEI','EOS','1000SHIB','NEAR','STORJ',
               '1000FLOKI','MKR','CYBER','UNI','STRAX',
               'BLUR','SUSHI','WAVES','MASK','MANA',
               'EGLD','AAVE','NEO','FET','TRX','GRT','ALGO','STX','XLM']

params_dict = {}
for freq in ['5T','15T','1h','4h']:
    params_dict[freq] = {}
    for coin in symbol_list:
        params_dict[freq][coin] = {}
        for direction in ['long','short']:
            params_dict[freq][coin][direction] = {}
            i = 0
            try:
                params_df = pd.read_csv(f'opt/{freq}/{coin}/{direction}_record_df.csv').drop(columns=['Unnamed: 0'])
                for _ , row in params_df[params_df['Sharpe Ratio']>2].iterrows():
                    params_dict[freq][coin][direction][str(i)] = row['params']
                    i += 1
            except Exception as e:
                pass
        try:
            if len(params_dict[freq][coin]['long'])==0 or len(params_dict[freq][coin]['short']==0):
                params_dict[freq].pop(coin)
        except:
            pass
            
filename = "params.json"

with open(filename, 'w') as file:
    json.dump(params_dict, file, indent=4)

# %%
params_dict
# Out:
# {'5T': {'ETH': {'long': [], 'short': []},
#   'BTC': {'long': [], 'short': []},
#   'BNB': {'long': [], 'short': []},
#   'SOL': {'long': [], 'short': []},
#   'MATIC': {'long': [], 'short': []},
#   'XRP': {'long': [], 'short': []},
#   'DYDX': {'long': [], 'short': []},
#   'AVAX': {'long': [], 'short': []},
#   'LINK': {'long': [], 'short': []},
#   'GAS': {'long': [], 'short': []},
#   'DOGE': {'long': [], 'short': []},
#   'ORDI': {'long': [], 'short': []},
#   'TRB': {'long': [], 'short': []},
#   'WLD': {'long': [], 'short': []},
#   'ADA': {'long': [], 'short': []},
#   'OP': {'long': [], 'short': []},
#   'FIL': {'long': [], 'short': []},
#   'ZRX': {'long': [], 'short': []},
#   'LTC': {'long': [], 'short': []},
#   'RUNE': {'long': [], 'short': []},
#   'ATOM': {'long': [], 'short': []},
#   'ARB': {'long': ["{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 280, 'multiplier': 2.0}",
#     "{'window_size': 280, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.0}"],
#    'short': ["{'window_size': 288, 'multiplier': 2.0}",
#     "{'window_size': 288, 'multiplier': 2.5}",
#     "{'window_size': 316, 'multiplier': 2.5}",
#     "{'window_size': 316, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.5}",
#     "{'window_size': 292, 'multiplier': 2.5}",
#     "{'window_size': 292, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.5}",
#     "{'window_size': 296, 'multiplier': 2.0}",
#     "{'window_size': 296, 'multiplier': 2.5}"]},
#   'GMT': {'long': [], 'short': []},
#   'ETC': {'long': [], 'short': []},
#   'ARK': {'long': [], 'short': []},
#   'BCH': {'long': [], 'short': []},
#   'DOT': {'long': [], 'short': []},
#   '1000PEPE': {'long': [], 'short': []},
#   'LDO': {'long': [], 'short': []},
#   'SUI': {'long': [], 'short': []},
#   'GALA': {'long': [], 'short': []},
#   'CAKE': {'long': [], 'short': []},
#   'APE': {'long': [], 'short': []},
#   'INJ': {'long': [], 'short': []},
#   'FTM': {'long': [], 'short': []},
#   'APT': {'long': ["{'window_size': 228, 'multiplier': 2.5}",
#     "{'window_size': 228, 'multiplier': 2.0}",
#     "{'window_size': 232, 'multiplier': 2.0}",
#     "{'window_size': 232, 'multiplier': 2.5}",
#     "{'window_size': 308, 'multiplier': 2.5}",
#     "{'window_size': 308, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.5}",
#     "{'window_size': 240, 'multiplier': 2.5}",
#     "{'window_size': 240, 'multiplier': 2.0}"],
#    'short': []},
#   'YFI': {'long': [], 'short': []},
#   'OMG': {'long': [], 'short': []},
#   'SEI': {'long': [], 'short': []},
#   'EOS': {'long': [], 'short': []},
#   '1000SHIB': {'long': [], 'short': []},
#   'NEAR': {'long': [], 'short': []},
#   'STORJ': {'long': [], 'short': []},
#   '1000FLOKI': {'long': [], 'short': []},
#   'MKR': {'long': [], 'short': []},
#   'CYBER': {'long': [], 'short': []},
#   'UNI': {'long': [], 'short': []},
#   'STRAX': {'long': [], 'short': []},
#   'BLUR': {'long': ["{'window_size': 208, 'multiplier': 2.5}",
#     "{'window_size': 208, 'multiplier': 2.0}",
#     "{'window_size': 204, 'multiplier': 2.5}",
#     "{'window_size': 204, 'multiplier': 2.0}",
#     "{'window_size': 308, 'multiplier': 2.5}",
#     "{'window_size': 308, 'multiplier': 2.0}",
#     "{'window_size': 292, 'multiplier': 2.0}",
#     "{'window_size': 292, 'multiplier': 2.5}",
#     "{'window_size': 304, 'multiplier': 2.5}",
#     "{'window_size': 304, 'multiplier': 2.0}",
#     "{'window_size': 200, 'multiplier': 2.5}",
#     "{'window_size': 200, 'multiplier': 2.0}",
#     "{'window_size': 196, 'multiplier': 2.5}",
#     "{'window_size': 196, 'multiplier': 2.0}",
#     "{'window_size': 296, 'multiplier': 2.0}",
#     "{'window_size': 296, 'multiplier': 2.5}",
#     "{'window_size': 312, 'multiplier': 2.0}",
#     "{'window_size': 312, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.0}",
#     "{'window_size': 192, 'multiplier': 2.5}",
#     "{'window_size': 192, 'multiplier': 2.0}",
#     "{'window_size': 300, 'multiplier': 2.0}",
#     "{'window_size': 300, 'multiplier': 2.5}",
#     "{'window_size': 280, 'multiplier': 2.5}",
#     "{'window_size': 280, 'multiplier': 2.0}",
#     "{'window_size': 244, 'multiplier': 2.0}",
#     "{'window_size': 244, 'multiplier': 2.5}",
#     "{'window_size': 240, 'multiplier': 2.5}",
#     "{'window_size': 240, 'multiplier': 2.0}",
#     "{'window_size': 212, 'multiplier': 2.5}",
#     "{'window_size': 212, 'multiplier': 2.0}",
#     "{'window_size': 288, 'multiplier': 2.0}",
#     "{'window_size': 288, 'multiplier': 2.5}",
#     "{'window_size': 316, 'multiplier': 2.0}",
#     "{'window_size': 316, 'multiplier': 2.5}",
#     "{'window_size': 248, 'multiplier': 2.0}",
#     "{'window_size': 256, 'multiplier': 2.5}",
#     "{'window_size': 252, 'multiplier': 2.5}",
#     "{'window_size': 252, 'multiplier': 2.0}",
#     "{'window_size': 248, 'multiplier': 2.5}",
#     "{'window_size': 256, 'multiplier': 2.0}",
#     "{'window_size': 180, 'multiplier': 2.5}",
#     "{'window_size': 180, 'multiplier': 2.0}",
#     "{'window_size': 284, 'multiplier': 2.5}",
#     "{'window_size': 284, 'multiplier': 2.0}",
#     "{'window_size': 268, 'multiplier': 2.5}",
#     "{'window_size': 268, 'multiplier': 2.0}",
#     "{'window_size': 264, 'multiplier': 2.5}",
#     "{'window_size': 264, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.5}",
#     "{'window_size': 236, 'multiplier': 2.0}",
#     "{'window_size': 176, 'multiplier': 2.5}",
#     "{'window_size': 176, 'multiplier': 2.0}",
#     "{'window_size': 320, 'multiplier': 2.0}",
#     "{'window_size': 320, 'multiplier': 2.5}",
#     "{'window_size': 336, 'multiplier': 2.5}",
#     "{'window_size': 336, 'multiplier': 2.0}"],
#    'short': ["{'window_size': 236, 'multiplier': 2.5}",
#     "{'window_size': 236, 'multiplier': 2.0}",
#     "{'window_size': 212, 'multiplier': 2.5}",
#     "{'window_size': 212, 'multiplier': 2.0}",
#     "{'window_size': 200, 'multiplier': 2.0}",
#     "{'window_size': 200, 'multiplier': 2.5}",
#     "{'window_size': 196, 'multiplier': 2.0}",
#     "{'window_size': 196, 'multiplier': 2.5}",
#     "{'window_size': 204, 'multiplier': 2.0}",
#     "{'window_size': 204, 'multiplier': 2.5}",
#     "{'window_size': 208, 'multiplier': 2.0}",
#     "{'window_size': 208, 'multiplier': 2.5}",
#     "{'window_size': 192, 'multiplier': 2.0}",
#     "{'window_size': 192, 'multiplier': 2.5}",
#     "{'window_size': 184, 'multiplier': 2.5}",
#     "{'window_size': 184, 'multiplier': 2.0}",
#     "{'window_size': 188, 'multiplier': 2.5}",
#     "{'window_size': 188, 'multiplier': 2.0}",
#     "{'window_size': 220, 'multiplier': 2.5}",
#     "{'window_size': 220, 'multiplier': 2.0}",
#     "{'window_size': 216, 'multiplier': 2.5}",
#     "{'window_size': 216, 'multiplier': 2.0}",
#     "{'window_size': 240, 'multiplier': 2.0}",
#     "{'window_size': 240, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 248, 'multiplier': 2.5}",
#     "{'window_size': 248, 'multiplier': 2.0}",
#     "{'window_size': 252, 'multiplier': 2.0}",
#     "{'window_size': 252, 'multiplier': 2.5}",
#     "{'window_size': 180, 'multiplier': 2.5}",
#     "{'window_size': 180, 'multiplier': 2.0}",
#     "{'window_size': 232, 'multiplier': 2.0}",
#     "{'window_size': 232, 'multiplier': 2.5}",
#     "{'window_size': 176, 'multiplier': 2.5}",
#     "{'window_size': 176, 'multiplier': 2.0}",
#     "{'window_size': 88, 'multiplier': 2.0}",
#     "{'window_size': 88, 'multiplier': 2.5}",
#     "{'window_size': 224, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.5}",
#     "{'window_size': 244, 'multiplier': 2.0}",
#     "{'window_size': 244, 'multiplier': 2.5}",
#     "{'window_size': 228, 'multiplier': 2.5}",
#     "{'window_size': 228, 'multiplier': 2.0}",
#     "{'window_size': 80, 'multiplier': 2.5}",
#     "{'window_size': 80, 'multiplier': 2.0}",
#     "{'window_size': 260, 'multiplier': 2.0}",
#     "{'window_size': 260, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.0}",
#     "{'window_size': 172, 'multiplier': 2.0}",
#     "{'window_size': 172, 'multiplier': 2.5}",
#     "{'window_size': 76, 'multiplier': 2.5}",
#     "{'window_size': 76, 'multiplier': 2.0}",
#     "{'window_size': 256, 'multiplier': 2.5}",
#     "{'window_size': 256, 'multiplier': 2.0}",
#     "{'window_size': 392, 'multiplier': 2.5}",
#     "{'window_size': 396, 'multiplier': 2.0}",
#     "{'window_size': 392, 'multiplier': 2.0}",
#     "{'window_size': 396, 'multiplier': 2.5}",
#     "{'window_size': 268, 'multiplier': 2.5}",
#     "{'window_size': 268, 'multiplier': 2.0}",
#     "{'window_size': 264, 'multiplier': 2.5}",
#     "{'window_size': 264, 'multiplier': 2.0}",
#     "{'window_size': 84, 'multiplier': 2.0}",
#     "{'window_size': 84, 'multiplier': 2.5}",
#     "{'window_size': 48, 'multiplier': 2.0}",
#     "{'window_size': 48, 'multiplier': 2.5}",
#     "{'window_size': 124, 'multiplier': 2.0}",
#     "{'window_size': 124, 'multiplier': 2.5}",
#     "{'window_size': 148, 'multiplier': 2.0}",
#     "{'window_size': 148, 'multiplier': 2.5}",
#     "{'window_size': 24, 'multiplier': 2.0}",
#     "{'window_size': 24, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 120, 'multiplier': 2.5}",
#     "{'window_size': 120, 'multiplier': 2.0}",
#     "{'window_size': 28, 'multiplier': 2.0}",
#     "{'window_size': 28, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 112, 'multiplier': 2.0}",
#     "{'window_size': 112, 'multiplier': 2.5}",
#     "{'window_size': 132, 'multiplier': 2.5}",
#     "{'window_size': 132, 'multiplier': 2.0}",
#     "{'window_size': 116, 'multiplier': 2.5}",
#     "{'window_size': 116, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 68, 'multiplier': 2.5}",
#     "{'window_size': 68, 'multiplier': 2.0}",
#     "{'window_size': 108, 'multiplier': 2.5}",
#     "{'window_size': 108, 'multiplier': 2.0}",
#     "{'window_size': 152, 'multiplier': 2.0}",
#     "{'window_size': 152, 'multiplier': 2.5}",
#     "{'window_size': 160, 'multiplier': 2.5}",
#     "{'window_size': 160, 'multiplier': 2.0}",
#     "{'window_size': 348, 'multiplier': 2.0}",
#     "{'window_size': 348, 'multiplier': 2.5}"]},
#   'SUSHI': {'long': [], 'short': []},
#   'WAVES': {'long': [], 'short': []},
#   'MASK': {'long': [], 'short': []},
#   'MANA': {'long': [], 'short': []},
#   'EGLD': {'long': [], 'short': []},
#   'AAVE': {'long': [], 'short': []},
#   'NEO': {'long': [], 'short': []},
#   'FET': {'long': ["{'window_size': 232, 'multiplier': 2.5}",
#     "{'window_size': 232, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.5}",
#     "{'window_size': 224, 'multiplier': 2.5}",
#     "{'window_size': 224, 'multiplier': 2.0}",
#     "{'window_size': 220, 'multiplier': 2.5}",
#     "{'window_size': 220, 'multiplier': 2.0}",
#     "{'window_size': 228, 'multiplier': 2.0}",
#     "{'window_size': 228, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 184, 'multiplier': 2.5}",
#     "{'window_size': 184, 'multiplier': 2.0}"]},
#   'TRX': {'long': [], 'short': []},
#   'GRT': {'long': [], 'short': []},
#   'ALGO': {'long': [], 'short': []},
#   'STX': {'long': ["{'window_size': 172, 'multiplier': 2.0}",
#     "{'window_size': 172, 'multiplier': 2.5}",
#     "{'window_size': 352, 'multiplier': 2.0}",
#     "{'window_size': 352, 'multiplier': 2.5}",
#     "{'window_size': 180, 'multiplier': 2.0}",
#     "{'window_size': 180, 'multiplier': 2.5}",
#     "{'window_size': 264, 'multiplier': 2.0}",
#     "{'window_size': 264, 'multiplier': 2.5}",
#     "{'window_size': 212, 'multiplier': 2.0}",
#     "{'window_size': 212, 'multiplier': 2.5}",
#     "{'window_size': 268, 'multiplier': 2.5}",
#     "{'window_size': 268, 'multiplier': 2.0}",
#     "{'window_size': 348, 'multiplier': 2.0}",
#     "{'window_size': 348, 'multiplier': 2.5}",
#     "{'window_size': 184, 'multiplier': 2.5}",
#     "{'window_size': 184, 'multiplier': 2.0}",
#     "{'window_size': 164, 'multiplier': 2.0}",
#     "{'window_size': 164, 'multiplier': 2.5}",
#     "{'window_size': 176, 'multiplier': 2.0}",
#     "{'window_size': 176, 'multiplier': 2.5}",
#     "{'window_size': 372, 'multiplier': 2.0}",
#     "{'window_size': 372, 'multiplier': 2.5}",
#     "{'window_size': 356, 'multiplier': 2.5}",
#     "{'window_size': 356, 'multiplier': 2.0}",
#     "{'window_size': 192, 'multiplier': 2.5}",
#     "{'window_size': 192, 'multiplier': 2.0}",
#     "{'window_size': 168, 'multiplier': 2.0}",
#     "{'window_size': 168, 'multiplier': 2.5}",
#     "{'window_size': 208, 'multiplier': 2.0}",
#     "{'window_size': 208, 'multiplier': 2.5}",
#     "{'window_size': 360, 'multiplier': 2.0}",
#     "{'window_size': 360, 'multiplier': 2.5}",
#     "{'window_size': 368, 'multiplier': 2.5}",
#     "{'window_size': 368, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.5}",
#     "{'window_size': 216, 'multiplier': 2.5}",
#     "{'window_size': 216, 'multiplier': 2.0}",
#     "{'window_size': 196, 'multiplier': 2.0}",
#     "{'window_size': 196, 'multiplier': 2.5}",
#     "{'window_size': 160, 'multiplier': 2.5}",
#     "{'window_size': 160, 'multiplier': 2.0}",
#     "{'window_size': 260, 'multiplier': 2.5}",
#     "{'window_size': 260, 'multiplier': 2.0}",
#     "{'window_size': 152, 'multiplier': 2.0}",
#     "{'window_size': 152, 'multiplier': 2.5}",
#     "{'window_size': 188, 'multiplier': 2.5}",
#     "{'window_size': 188, 'multiplier': 2.0}",
#     "{'window_size': 220, 'multiplier': 2.0}",
#     "{'window_size': 220, 'multiplier': 2.5}",
#     "{'window_size': 232, 'multiplier': 2.0}",
#     "{'window_size': 232, 'multiplier': 2.5}"],
#    'short': []},
#   'XLM': {'long': [], 'short': []}},
#  '15T': {'ETH': {'long': [], 'short': []},
#   'BTC': {'long': [], 'short': []},
#   'BNB': {'long': [], 'short': []},
#   'SOL': {'long': [], 'short': []},
#   'MATIC': {'long': [],
#    'short': ["{'window_size': 228, 'multiplier': 2.0}",
#     "{'window_size': 228, 'multiplier': 2.5}",
#     "{'window_size': 224, 'multiplier': 2.5}",
#     "{'window_size': 224, 'multiplier': 2.0}"]},
#   'XRP': {'long': [], 'short': []},
#   'DYDX': {'long': ["{'window_size': 164, 'multiplier': 2.5}",
#     "{'window_size': 164, 'multiplier': 2.0}",
#     "{'window_size': 176, 'multiplier': 2.5}",
#     "{'window_size': 176, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.5}",
#     "{'window_size': 180, 'multiplier': 2.5}",
#     "{'window_size': 180, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.5}",
#     "{'window_size': 220, 'multiplier': 2.5}",
#     "{'window_size': 220, 'multiplier': 2.0}",
#     "{'window_size': 240, 'multiplier': 2.0}",
#     "{'window_size': 240, 'multiplier': 2.5}"],
#    'short': []},
#   'AVAX': {'long': [],
#    'short': ["{'window_size': 232, 'multiplier': 2.5}",
#     "{'window_size': 232, 'multiplier': 2.0}",
#     "{'window_size': 336, 'multiplier': 2.5}",
#     "{'window_size': 336, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.5}",
#     "{'window_size': 224, 'multiplier': 2.0}",
#     "{'window_size': 228, 'multiplier': 2.5}",
#     "{'window_size': 228, 'multiplier': 2.0}",
#     "{'window_size': 220, 'multiplier': 2.0}",
#     "{'window_size': 220, 'multiplier': 2.5}"]},
#   'LINK': {'long': ["{'window_size': 88, 'multiplier': 2.0}",
#     "{'window_size': 88, 'multiplier': 2.5}"],
#    'short': []},
#   'GAS': {'long': [], 'short': []},
#   'DOGE': {'long': [], 'short': []},
#   'ORDI': {'long': [], 'short': []},
#   'TRB': {'long': [], 'short': []},
#   'WLD': {'long': [], 'short': []},
#   'ADA': {'long': [], 'short': []},
#   'OP': {'long': ["{'window_size': 84, 'multiplier': 2.0}",
#     "{'window_size': 84, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 208, 'multiplier': 2.5}",
#     "{'window_size': 208, 'multiplier': 2.0}"]},
#   'FIL': {'long': [], 'short': []},
#   'ZRX': {'long': [], 'short': []},
#   'LTC': {'long': [], 'short': []},
#   'RUNE': {'long': [],
#    'short': ["{'window_size': 200, 'multiplier': 2.0}",
#     "{'window_size': 200, 'multiplier': 2.5}",
#     "{'window_size': 192, 'multiplier': 2.0}",
#     "{'window_size': 192, 'multiplier': 2.5}",
#     "{'window_size': 196, 'multiplier': 2.0}",
#     "{'window_size': 196, 'multiplier': 2.5}"]},
#   'ATOM': {'long': [], 'short': []},
#   'ARB': {'long': ["{'window_size': 396, 'multiplier': 2.5}",
#     "{'window_size': 396, 'multiplier': 2.0}",
#     "{'window_size': 388, 'multiplier': 2.0}",
#     "{'window_size': 388, 'multiplier': 2.5}",
#     "{'window_size': 392, 'multiplier': 2.0}",
#     "{'window_size': 392, 'multiplier': 2.5}",
#     "{'window_size': 384, 'multiplier': 2.5}",
#     "{'window_size': 384, 'multiplier': 2.0}",
#     "{'window_size': 360, 'multiplier': 2.5}",
#     "{'window_size': 360, 'multiplier': 2.0}",
#     "{'window_size': 380, 'multiplier': 2.5}",
#     "{'window_size': 380, 'multiplier': 2.0}",
#     "{'window_size': 332, 'multiplier': 2.0}",
#     "{'window_size': 332, 'multiplier': 2.5}",
#     "{'window_size': 316, 'multiplier': 2.0}",
#     "{'window_size': 316, 'multiplier': 2.5}",
#     "{'window_size': 312, 'multiplier': 2.5}",
#     "{'window_size': 312, 'multiplier': 2.0}",
#     "{'window_size': 336, 'multiplier': 2.5}",
#     "{'window_size': 336, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.5}",
#     "{'window_size': 324, 'multiplier': 2.0}",
#     "{'window_size': 324, 'multiplier': 2.5}",
#     "{'window_size': 340, 'multiplier': 2.0}",
#     "{'window_size': 340, 'multiplier': 2.5}",
#     "{'window_size': 356, 'multiplier': 2.0}",
#     "{'window_size': 356, 'multiplier': 2.5}",
#     "{'window_size': 320, 'multiplier': 2.5}",
#     "{'window_size': 320, 'multiplier': 2.0}",
#     "{'window_size': 344, 'multiplier': 2.0}",
#     "{'window_size': 344, 'multiplier': 2.5}",
#     "{'window_size': 328, 'multiplier': 2.0}",
#     "{'window_size': 328, 'multiplier': 2.5}",
#     "{'window_size': 376, 'multiplier': 2.5}",
#     "{'window_size': 376, 'multiplier': 2.0}",
#     "{'window_size': 308, 'multiplier': 2.5}",
#     "{'window_size': 308, 'multiplier': 2.0}",
#     "{'window_size': 280, 'multiplier': 2.5}",
#     "{'window_size': 280, 'multiplier': 2.0}",
#     "{'window_size': 352, 'multiplier': 2.0}",
#     "{'window_size': 352, 'multiplier': 2.5}",
#     "{'window_size': 348, 'multiplier': 2.0}",
#     "{'window_size': 348, 'multiplier': 2.5}",
#     "{'window_size': 372, 'multiplier': 2.0}",
#     "{'window_size': 372, 'multiplier': 2.5}",
#     "{'window_size': 368, 'multiplier': 2.0}",
#     "{'window_size': 368, 'multiplier': 2.5}",
#     "{'window_size': 304, 'multiplier': 2.0}",
#     "{'window_size': 304, 'multiplier': 2.5}",
#     "{'window_size': 300, 'multiplier': 2.0}",
#     "{'window_size': 300, 'multiplier': 2.5}",
#     "{'window_size': 296, 'multiplier': 2.0}",
#     "{'window_size': 296, 'multiplier': 2.5}",
#     "{'window_size': 84, 'multiplier': 2.5}",
#     "{'window_size': 84, 'multiplier': 2.0}",
#     "{'window_size': 288, 'multiplier': 2.0}",
#     "{'window_size': 288, 'multiplier': 2.5}",
#     "{'window_size': 20, 'multiplier': 2.5}",
#     "{'window_size': 20, 'multiplier': 2.0}",
#     "{'window_size': 284, 'multiplier': 2.0}",
#     "{'window_size': 284, 'multiplier': 2.5}",
#     "{'window_size': 216, 'multiplier': 2.0}",
#     "{'window_size': 216, 'multiplier': 2.5}",
#     "{'window_size': 28, 'multiplier': 2.0}",
#     "{'window_size': 28, 'multiplier': 2.5}",
#     "{'window_size': 196, 'multiplier': 2.5}",
#     "{'window_size': 196, 'multiplier': 2.0}",
#     "{'window_size': 292, 'multiplier': 2.0}",
#     "{'window_size': 292, 'multiplier': 2.5}",
#     "{'window_size': 36, 'multiplier': 2.0}",
#     "{'window_size': 36, 'multiplier': 2.5}",
#     "{'window_size': 32, 'multiplier': 2.5}",
#     "{'window_size': 32, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 256, 'multiplier': 2.0}",
#     "{'window_size': 256, 'multiplier': 2.5}",
#     "{'window_size': 260, 'multiplier': 2.0}",
#     "{'window_size': 260, 'multiplier': 2.5}",
#     "{'window_size': 68, 'multiplier': 2.5}",
#     "{'window_size': 68, 'multiplier': 2.0}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 264, 'multiplier': 2.0}",
#     "{'window_size': 264, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 300, 'multiplier': 2.0}",
#     "{'window_size': 300, 'multiplier': 2.5}",
#     "{'window_size': 308, 'multiplier': 2.0}",
#     "{'window_size': 308, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 312, 'multiplier': 2.5}",
#     "{'window_size': 312, 'multiplier': 2.0}",
#     "{'window_size': 356, 'multiplier': 2.0}",
#     "{'window_size': 356, 'multiplier': 2.5}",
#     "{'window_size': 296, 'multiplier': 2.5}",
#     "{'window_size': 296, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 316, 'multiplier': 2.0}",
#     "{'window_size': 316, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.0}",
#     "{'window_size': 352, 'multiplier': 2.0}",
#     "{'window_size': 352, 'multiplier': 2.5}",
#     "{'window_size': 288, 'multiplier': 2.5}",
#     "{'window_size': 288, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.5}",
#     "{'window_size': 364, 'multiplier': 2.0}",
#     "{'window_size': 360, 'multiplier': 2.5}",
#     "{'window_size': 360, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 304, 'multiplier': 2.5}",
#     "{'window_size': 304, 'multiplier': 2.0}",
#     "{'window_size': 280, 'multiplier': 2.5}",
#     "{'window_size': 280, 'multiplier': 2.0}"]},
#   'GMT': {'long': ["{'window_size': 392, 'multiplier': 2.5}",
#     "{'window_size': 392, 'multiplier': 2.0}",
#     "{'window_size': 396, 'multiplier': 2.5}",
#     "{'window_size': 396, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.5}",
#     "{'window_size': 364, 'multiplier': 2.0}",
#     "{'window_size': 368, 'multiplier': 2.5}",
#     "{'window_size': 368, 'multiplier': 2.0}",
#     "{'window_size': 388, 'multiplier': 2.0}",
#     "{'window_size': 388, 'multiplier': 2.5}",
#     "{'window_size': 380, 'multiplier': 2.5}",
#     "{'window_size': 380, 'multiplier': 2.0}",
#     "{'window_size': 352, 'multiplier': 2.0}",
#     "{'window_size': 352, 'multiplier': 2.5}",
#     "{'window_size': 384, 'multiplier': 2.0}",
#     "{'window_size': 384, 'multiplier': 2.5}",
#     "{'window_size': 356, 'multiplier': 2.0}",
#     "{'window_size': 356, 'multiplier': 2.5}",
#     "{'window_size': 372, 'multiplier': 2.0}",
#     "{'window_size': 372, 'multiplier': 2.5}"],
#    'short': []},
#   'ETC': {'long': [], 'short': []},
#   'ARK': {'long': [], 'short': []},
#   'BCH': {'long': [], 'short': []},
#   'DOT': {'long': [], 'short': []},
#   '1000PEPE': {'long': [], 'short': []},
#   'LDO': {'long': [], 'short': []},
#   'SUI': {'long': [], 'short': []},
#   'GALA': {'long': [], 'short': []},
#   'CAKE': {'long': [], 'short': []},
#   'APE': {'long': [], 'short': []},
#   'INJ': {'long': [], 'short': []},
#   'FTM': {'long': [],
#    'short': ["{'window_size': 332, 'multiplier': 2.0}",
#     "{'window_size': 332, 'multiplier': 2.5}"]},
#   'APT': {'long': ["{'window_size': 380, 'multiplier': 2.5}",
#     "{'window_size': 380, 'multiplier': 2.0}",
#     "{'window_size': 148, 'multiplier': 2.0}",
#     "{'window_size': 148, 'multiplier': 2.5}",
#     "{'window_size': 112, 'multiplier': 2.5}",
#     "{'window_size': 112, 'multiplier': 2.0}",
#     "{'window_size': 340, 'multiplier': 2.5}",
#     "{'window_size': 340, 'multiplier': 2.0}",
#     "{'window_size': 344, 'multiplier': 2.5}",
#     "{'window_size': 344, 'multiplier': 2.0}",
#     "{'window_size': 180, 'multiplier': 2.0}",
#     "{'window_size': 180, 'multiplier': 2.5}"],
#    'short': []},
#   'YFI': {'long': [], 'short': []},
#   'OMG': {'long': [], 'short': []},
#   'SEI': {'long': [], 'short': []},
#   'EOS': {'long': [], 'short': []},
#   '1000SHIB': {'long': [], 'short': []},
#   'NEAR': {'long': [], 'short': []},
#   'STORJ': {'long': [], 'short': []},
#   '1000FLOKI': {'long': [], 'short': []},
#   'MKR': {'long': [], 'short': []},
#   'CYBER': {'long': [], 'short': []},
#   'UNI': {'long': [], 'short': []},
#   'STRAX': {'long': [], 'short': []},
#   'BLUR': {'long': ["{'window_size': 104, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.0}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 88, 'multiplier': 2.0}",
#     "{'window_size': 88, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 84, 'multiplier': 2.0}",
#     "{'window_size': 84, 'multiplier': 2.5}",
#     "{'window_size': 80, 'multiplier': 2.5}",
#     "{'window_size': 80, 'multiplier': 2.0}",
#     "{'window_size': 60, 'multiplier': 2.5}",
#     "{'window_size': 60, 'multiplier': 2.0}",
#     "{'window_size': 68, 'multiplier': 2.0}",
#     "{'window_size': 68, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 136, 'multiplier': 2.5}",
#     "{'window_size': 136, 'multiplier': 2.0}",
#     "{'window_size': 64, 'multiplier': 2.0}",
#     "{'window_size': 64, 'multiplier': 2.5}",
#     "{'window_size': 80, 'multiplier': 2.5}",
#     "{'window_size': 80, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 68, 'multiplier': 2.0}",
#     "{'window_size': 68, 'multiplier': 2.5}",
#     "{'window_size': 60, 'multiplier': 2.0}",
#     "{'window_size': 60, 'multiplier': 2.5}",
#     "{'window_size': 32, 'multiplier': 2.0}",
#     "{'window_size': 32, 'multiplier': 2.5}",
#     "{'window_size': 36, 'multiplier': 2.0}",
#     "{'window_size': 36, 'multiplier': 2.5}",
#     "{'window_size': 84, 'multiplier': 2.5}",
#     "{'window_size': 84, 'multiplier': 2.0}",
#     "{'window_size': 12, 'multiplier': 2.5}",
#     "{'window_size': 12, 'multiplier': 2.0}",
#     "{'window_size': 132, 'multiplier': 2.5}",
#     "{'window_size': 132, 'multiplier': 2.0}",
#     "{'window_size': 124, 'multiplier': 2.0}",
#     "{'window_size': 124, 'multiplier': 2.5}"]},
#   'SUSHI': {'long': [],
#    'short': ["{'window_size': 384, 'multiplier': 2.5}",
#     "{'window_size': 384, 'multiplier': 2.0}"]},
#   'WAVES': {'long': [], 'short': []},
#   'MASK': {'long': [], 'short': []},
#   'MANA': {'long': [], 'short': []},
#   'EGLD': {'long': [], 'short': []},
#   'AAVE': {'long': [], 'short': []},
#   'NEO': {'long': [], 'short': []},
#   'FET': {'long': ["{'window_size': 120, 'multiplier': 2.5}",
#     "{'window_size': 120, 'multiplier': 2.0}",
#     "{'window_size': 104, 'multiplier': 2.0}",
#     "{'window_size': 104, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 80, 'multiplier': 2.0}",
#     "{'window_size': 80, 'multiplier': 2.5}",
#     "{'window_size': 84, 'multiplier': 2.5}",
#     "{'window_size': 84, 'multiplier': 2.0}",
#     "{'window_size': 76, 'multiplier': 2.0}",
#     "{'window_size': 76, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.0}"]},
#   'TRX': {'long': [], 'short': []},
#   'GRT': {'long': [], 'short': []},
#   'ALGO': {'long': [], 'short': []},
#   'STX': {'long': ["{'window_size': 60, 'multiplier': 2.5}",
#     "{'window_size': 60, 'multiplier': 2.0}",
#     "{'window_size': 56, 'multiplier': 2.5}",
#     "{'window_size': 56, 'multiplier': 2.0}",
#     "{'window_size': 52, 'multiplier': 2.5}",
#     "{'window_size': 52, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 120, 'multiplier': 2.5}",
#     "{'window_size': 120, 'multiplier': 2.0}",
#     "{'window_size': 116, 'multiplier': 2.5}",
#     "{'window_size': 116, 'multiplier': 2.0}",
#     "{'window_size': 68, 'multiplier': 2.0}",
#     "{'window_size': 68, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.0}",
#     "{'window_size': 64, 'multiplier': 2.5}",
#     "{'window_size': 228, 'multiplier': 2.5}",
#     "{'window_size': 228, 'multiplier': 2.0}",
#     "{'window_size': 48, 'multiplier': 2.0}",
#     "{'window_size': 48, 'multiplier': 2.5}",
#     "{'window_size': 88, 'multiplier': 2.0}",
#     "{'window_size': 88, 'multiplier': 2.5}",
#     "{'window_size': 124, 'multiplier': 2.0}",
#     "{'window_size': 124, 'multiplier': 2.5}",
#     "{'window_size': 44, 'multiplier': 2.5}",
#     "{'window_size': 44, 'multiplier': 2.0}",
#     "{'window_size': 12, 'multiplier': 2.5}",
#     "{'window_size': 12, 'multiplier': 2.0}",
#     "{'window_size': 304, 'multiplier': 2.5}",
#     "{'window_size': 304, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 320, 'multiplier': 2.0}",
#     "{'window_size': 320, 'multiplier': 2.5}",
#     "{'window_size': 336, 'multiplier': 2.5}",
#     "{'window_size': 336, 'multiplier': 2.0}",
#     "{'window_size': 48, 'multiplier': 2.5}",
#     "{'window_size': 48, 'multiplier': 2.0}",
#     "{'window_size': 340, 'multiplier': 2.0}",
#     "{'window_size': 340, 'multiplier': 2.5}",
#     "{'window_size': 344, 'multiplier': 2.0}",
#     "{'window_size': 344, 'multiplier': 2.5}"]},
#   'XLM': {'long': [], 'short': []}},
#  '1h': {'ETH': {'long': [], 'short': []},
#   'BTC': {'long': [], 'short': []},
#   'BNB': {'long': [], 'short': []},
#   'SOL': {'long': [],
#    'short': ["{'window_size': 20, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.5}"]},
#   'MATIC': {'long': [],
#    'short': ["{'window_size': 56, 'multiplier': 2.0}",
#     "{'window_size': 56, 'multiplier': 2.5}",
#     "{'window_size': 76, 'multiplier': 2.5}",
#     "{'window_size': 76, 'multiplier': 2.0}"]},
#   'XRP': {'long': [], 'short': []},
#   'DYDX': {'long': ["{'window_size': 56, 'multiplier': 2.5}",
#     "{'window_size': 56, 'multiplier': 2.0}",
#     "{'window_size': 60, 'multiplier': 2.5}",
#     "{'window_size': 60, 'multiplier': 2.0}"],
#    'short': ["{'window_size': 364, 'multiplier': 2.5}",
#     "{'window_size': 364, 'multiplier': 2.0}",
#     "{'window_size': 396, 'multiplier': 2.5}",
#     "{'window_size': 396, 'multiplier': 2.0}",
#     "{'window_size': 304, 'multiplier': 2.5}",
#     "{'window_size': 304, 'multiplier': 2.0}",
#     "{'window_size': 336, 'multiplier': 2.0}",
#     "{'window_size': 336, 'multiplier': 2.5}",
#     "{'window_size': 372, 'multiplier': 2.0}",
#     "{'window_size': 372, 'multiplier': 2.5}",
#     "{'window_size': 388, 'multiplier': 2.5}",
#     "{'window_size': 388, 'multiplier': 2.0}"]},
#   'AVAX': {'long': ["{'window_size': 248, 'multiplier': 2.5}",
#     "{'window_size': 248, 'multiplier': 2.0}"],
#    'short': ["{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}"]},
#   'LINK': {'long': [], 'short': []},
#   'GAS': {'long': [], 'short': []},
#   'DOGE': {'long': [], 'short': []},
#   'ORDI': {'long': [], 'short': []},
#   'TRB': {'long': [],
#    'short': ["{'window_size': 220, 'multiplier': 2.5}",
#     "{'window_size': 220, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.5}"]},
#   'WLD': {'long': [], 'short': []},
#   'ADA': {'long': [],
#    'short': ["{'window_size': 380, 'multiplier': 2.0}",
#     "{'window_size': 380, 'multiplier': 2.5}",
#     "{'window_size': 316, 'multiplier': 2.5}",
#     "{'window_size': 316, 'multiplier': 2.0}"]},
#   'OP': {'long': ["{'window_size': 132, 'multiplier': 2.5}",
#     "{'window_size': 132, 'multiplier': 2.0}",
#     "{'window_size': 128, 'multiplier': 2.5}",
#     "{'window_size': 128, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 116, 'multiplier': 2.5}",
#     "{'window_size': 116, 'multiplier': 2.0}",
#     "{'window_size': 120, 'multiplier': 2.5}",
#     "{'window_size': 120, 'multiplier': 2.0}",
#     "{'window_size': 140, 'multiplier': 2.0}",
#     "{'window_size': 140, 'multiplier': 2.5}",
#     "{'window_size': 136, 'multiplier': 2.5}",
#     "{'window_size': 136, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.5}",
#     "{'window_size': 20, 'multiplier': 2.0}",
#     "{'window_size': 168, 'multiplier': 2.0}",
#     "{'window_size': 168, 'multiplier': 2.5}",
#     "{'window_size': 176, 'multiplier': 2.0}",
#     "{'window_size': 176, 'multiplier': 2.5}",
#     "{'window_size': 172, 'multiplier': 2.0}",
#     "{'window_size': 172, 'multiplier': 2.5}",
#     "{'window_size': 236, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.5}",
#     "{'window_size': 244, 'multiplier': 2.5}",
#     "{'window_size': 244, 'multiplier': 2.0}",
#     "{'window_size': 156, 'multiplier': 2.5}",
#     "{'window_size': 156, 'multiplier': 2.0}",
#     "{'window_size': 240, 'multiplier': 2.0}",
#     "{'window_size': 240, 'multiplier': 2.5}",
#     "{'window_size': 184, 'multiplier': 2.5}",
#     "{'window_size': 184, 'multiplier': 2.0}",
#     "{'window_size': 164, 'multiplier': 2.0}",
#     "{'window_size': 164, 'multiplier': 2.5}",
#     "{'window_size': 16, 'multiplier': 2.0}",
#     "{'window_size': 16, 'multiplier': 2.5}"],
#    'short': []},
#   'FIL': {'long': [], 'short': []},
#   'ZRX': {'long': [],
#    'short': ["{'window_size': 272, 'multiplier': 2.0}",
#     "{'window_size': 272, 'multiplier': 2.5}"]},
#   'LTC': {'long': [], 'short': []},
#   'RUNE': {'long': ["{'window_size': 44, 'multiplier': 2.5}",
#     "{'window_size': 44, 'multiplier': 2.0}",
#     "{'window_size': 356, 'multiplier': 2.0}",
#     "{'window_size': 356, 'multiplier': 2.5}",
#     "{'window_size': 376, 'multiplier': 2.5}",
#     "{'window_size': 376, 'multiplier': 2.0}",
#     "{'window_size': 372, 'multiplier': 2.5}",
#     "{'window_size': 372, 'multiplier': 2.0}",
#     "{'window_size': 368, 'multiplier': 2.0}",
#     "{'window_size': 368, 'multiplier': 2.5}",
#     "{'window_size': 364, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.5}",
#     "{'window_size': 88, 'multiplier': 2.5}",
#     "{'window_size': 88, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 320, 'multiplier': 2.0}",
#     "{'window_size': 320, 'multiplier': 2.5}",
#     "{'window_size': 276, 'multiplier': 2.5}",
#     "{'window_size': 276, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 76, 'multiplier': 2.0}",
#     "{'window_size': 76, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.0}"],
#    'short': ["{'window_size': 48, 'multiplier': 2.5}",
#     "{'window_size': 48, 'multiplier': 2.0}",
#     "{'window_size': 288, 'multiplier': 2.5}",
#     "{'window_size': 288, 'multiplier': 2.0}",
#     "{'window_size': 284, 'multiplier': 2.0}",
#     "{'window_size': 284, 'multiplier': 2.5}",
#     "{'window_size': 52, 'multiplier': 2.0}",
#     "{'window_size': 52, 'multiplier': 2.5}",
#     "{'window_size': 292, 'multiplier': 2.5}",
#     "{'window_size': 292, 'multiplier': 2.0}",
#     "{'window_size': 296, 'multiplier': 2.0}",
#     "{'window_size': 296, 'multiplier': 2.5}",
#     "{'window_size': 280, 'multiplier': 2.5}",
#     "{'window_size': 280, 'multiplier': 2.0}",
#     "{'window_size': 80, 'multiplier': 2.5}",
#     "{'window_size': 80, 'multiplier': 2.0}"]},
#   'ATOM': {'long': [], 'short': []},
#   'ARB': {'long': ["{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 228, 'multiplier': 2.5}",
#     "{'window_size': 228, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.5}",
#     "{'window_size': 252, 'multiplier': 2.0}",
#     "{'window_size': 252, 'multiplier': 2.5}",
#     "{'window_size': 84, 'multiplier': 2.5}",
#     "{'window_size': 84, 'multiplier': 2.0}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 216, 'multiplier': 2.5}",
#     "{'window_size': 216, 'multiplier': 2.0}",
#     "{'window_size': 220, 'multiplier': 2.5}",
#     "{'window_size': 220, 'multiplier': 2.0}",
#     "{'window_size': 104, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.0}",
#     "{'window_size': 212, 'multiplier': 2.5}",
#     "{'window_size': 212, 'multiplier': 2.0}",
#     "{'window_size': 80, 'multiplier': 2.5}",
#     "{'window_size': 80, 'multiplier': 2.0}",
#     "{'window_size': 232, 'multiplier': 2.0}",
#     "{'window_size': 232, 'multiplier': 2.5}",
#     "{'window_size': 248, 'multiplier': 2.5}",
#     "{'window_size': 248, 'multiplier': 2.0}",
#     "{'window_size': 240, 'multiplier': 2.0}",
#     "{'window_size': 240, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.0}",
#     "{'window_size': 64, 'multiplier': 2.5}",
#     "{'window_size': 16, 'multiplier': 2.0}",
#     "{'window_size': 16, 'multiplier': 2.5}",
#     "{'window_size': 356, 'multiplier': 2.0}",
#     "{'window_size': 356, 'multiplier': 2.5}",
#     "{'window_size': 68, 'multiplier': 2.0}",
#     "{'window_size': 68, 'multiplier': 2.5}",
#     "{'window_size': 396, 'multiplier': 2.5}",
#     "{'window_size': 396, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 108, 'multiplier': 2.5}",
#     "{'window_size': 108, 'multiplier': 2.0}",
#     "{'window_size': 128, 'multiplier': 2.5}",
#     "{'window_size': 128, 'multiplier': 2.0}",
#     "{'window_size': 88, 'multiplier': 2.5}",
#     "{'window_size': 88, 'multiplier': 2.0}",
#     "{'window_size': 372, 'multiplier': 2.5}",
#     "{'window_size': 372, 'multiplier': 2.0}",
#     "{'window_size': 380, 'multiplier': 2.5}",
#     "{'window_size': 380, 'multiplier': 2.0}",
#     "{'window_size': 376, 'multiplier': 2.0}",
#     "{'window_size': 376, 'multiplier': 2.5}",
#     "{'window_size': 392, 'multiplier': 2.5}",
#     "{'window_size': 392, 'multiplier': 2.0}",
#     "{'window_size': 24, 'multiplier': 2.0}",
#     "{'window_size': 24, 'multiplier': 2.5}",
#     "{'window_size': 388, 'multiplier': 2.5}",
#     "{'window_size': 388, 'multiplier': 2.0}",
#     "{'window_size': 384, 'multiplier': 2.0}",
#     "{'window_size': 384, 'multiplier': 2.5}",
#     "{'window_size': 368, 'multiplier': 2.5}",
#     "{'window_size': 368, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.5}",
#     "{'window_size': 364, 'multiplier': 2.0}",
#     "{'window_size': 76, 'multiplier': 2.0}",
#     "{'window_size': 76, 'multiplier': 2.5}",
#     "{'window_size': 32, 'multiplier': 2.5}",
#     "{'window_size': 32, 'multiplier': 2.0}",
#     "{'window_size': 112, 'multiplier': 2.0}",
#     "{'window_size': 112, 'multiplier': 2.5}",
#     "{'window_size': 244, 'multiplier': 2.0}",
#     "{'window_size': 244, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 244, 'multiplier': 2.0}",
#     "{'window_size': 244, 'multiplier': 2.5}",
#     "{'window_size': 240, 'multiplier': 2.5}",
#     "{'window_size': 240, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.5}",
#     "{'window_size': 248, 'multiplier': 2.5}",
#     "{'window_size': 248, 'multiplier': 2.0}",
#     "{'window_size': 256, 'multiplier': 2.0}",
#     "{'window_size': 256, 'multiplier': 2.5}",
#     "{'window_size': 76, 'multiplier': 2.5}",
#     "{'window_size': 76, 'multiplier': 2.0}",
#     "{'window_size': 252, 'multiplier': 2.0}",
#     "{'window_size': 252, 'multiplier': 2.5}",
#     "{'window_size': 24, 'multiplier': 2.5}",
#     "{'window_size': 24, 'multiplier': 2.0}",
#     "{'window_size': 260, 'multiplier': 2.0}",
#     "{'window_size': 260, 'multiplier': 2.5}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 232, 'multiplier': 2.5}",
#     "{'window_size': 232, 'multiplier': 2.0}",
#     "{'window_size': 376, 'multiplier': 2.0}",
#     "{'window_size': 376, 'multiplier': 2.5}"]},
#   'GMT': {'long': ["{'window_size': 20, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.5}",
#     "{'window_size': 136, 'multiplier': 2.0}",
#     "{'window_size': 136, 'multiplier': 2.5}",
#     "{'window_size': 144, 'multiplier': 2.0}",
#     "{'window_size': 144, 'multiplier': 2.5}",
#     "{'window_size': 140, 'multiplier': 2.0}",
#     "{'window_size': 140, 'multiplier': 2.5}",
#     "{'window_size': 112, 'multiplier': 2.0}",
#     "{'window_size': 112, 'multiplier': 2.5}",
#     "{'window_size': 148, 'multiplier': 2.0}",
#     "{'window_size': 148, 'multiplier': 2.5}",
#     "{'window_size': 168, 'multiplier': 2.0}",
#     "{'window_size': 168, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 80, 'multiplier': 2.0}",
#     "{'window_size': 80, 'multiplier': 2.5}",
#     "{'window_size': 172, 'multiplier': 2.0}",
#     "{'window_size': 172, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 164, 'multiplier': 2.0}",
#     "{'window_size': 164, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}"],
#    'short': []},
#   'ETC': {'long': ["{'window_size': 244, 'multiplier': 2.5}",
#     "{'window_size': 244, 'multiplier': 2.0}",
#     "{'window_size': 128, 'multiplier': 2.5}",
#     "{'window_size': 128, 'multiplier': 2.0}"],
#    'short': []},
#   'ARK': {'long': [], 'short': []},
#   'BCH': {'long': [], 'short': []},
#   'DOT': {'long': [], 'short': []},
#   '1000PEPE': {'long': [], 'short': []},
#   'LDO': {'long': ["{'window_size': 252, 'multiplier': 2.5}",
#     "{'window_size': 252, 'multiplier': 2.0}",
#     "{'window_size': 80, 'multiplier': 2.0}",
#     "{'window_size': 80, 'multiplier': 2.5}",
#     "{'window_size': 76, 'multiplier': 2.0}",
#     "{'window_size': 76, 'multiplier': 2.5}"],
#    'short': []},
#   'SUI': {'long': [], 'short': []},
#   'GALA': {'long': ["{'window_size': 108, 'multiplier': 2.5}",
#     "{'window_size': 108, 'multiplier': 2.0}",
#     "{'window_size': 104, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.0}",
#     "{'window_size': 112, 'multiplier': 2.5}",
#     "{'window_size': 112, 'multiplier': 2.0}"],
#    'short': []},
#   'CAKE': {'long': [], 'short': []},
#   'APE': {'long': ["{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.0}",
#     "{'window_size': 104, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}"],
#    'short': []},
#   'INJ': {'long': [], 'short': []},
#   'FTM': {'long': [],
#    'short': ["{'window_size': 80, 'multiplier': 2.5}",
#     "{'window_size': 80, 'multiplier': 2.0}"]},
#   'APT': {'long': ["{'window_size': 80, 'multiplier': 2.0}",
#     "{'window_size': 80, 'multiplier': 2.5}",
#     "{'window_size': 84, 'multiplier': 2.5}",
#     "{'window_size': 84, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 88, 'multiplier': 2.0}",
#     "{'window_size': 88, 'multiplier': 2.5}",
#     "{'window_size': 164, 'multiplier': 2.5}",
#     "{'window_size': 164, 'multiplier': 2.0}",
#     "{'window_size': 16, 'multiplier': 2.0}",
#     "{'window_size': 16, 'multiplier': 2.5}",
#     "{'window_size': 148, 'multiplier': 2.5}",
#     "{'window_size': 148, 'multiplier': 2.0}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 36, 'multiplier': 2.0}",
#     "{'window_size': 36, 'multiplier': 2.5}",
#     "{'window_size': 124, 'multiplier': 2.0}",
#     "{'window_size': 124, 'multiplier': 2.5}",
#     "{'window_size': 56, 'multiplier': 2.0}",
#     "{'window_size': 56, 'multiplier': 2.5}",
#     "{'window_size': 156, 'multiplier': 2.5}",
#     "{'window_size': 156, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.5}",
#     "{'window_size': 20, 'multiplier': 2.0}",
#     "{'window_size': 160, 'multiplier': 2.5}",
#     "{'window_size': 160, 'multiplier': 2.0}",
#     "{'window_size': 128, 'multiplier': 2.5}",
#     "{'window_size': 128, 'multiplier': 2.0}"],
#    'short': ["{'window_size': 232, 'multiplier': 2.5}",
#     "{'window_size': 232, 'multiplier': 2.0}"]},
#   'YFI': {'long': [], 'short': []},
#   'OMG': {'long': [], 'short': []},
#   'SEI': {'long': [], 'short': []},
#   'EOS': {'long': ["{'window_size': 148, 'multiplier': 2.0}",
#     "{'window_size': 148, 'multiplier': 2.5}",
#     "{'window_size': 144, 'multiplier': 2.5}",
#     "{'window_size': 144, 'multiplier': 2.0}",
#     "{'window_size': 152, 'multiplier': 2.5}",
#     "{'window_size': 152, 'multiplier': 2.0}",
#     "{'window_size': 156, 'multiplier': 2.5}",
#     "{'window_size': 156, 'multiplier': 2.0}",
#     "{'window_size': 136, 'multiplier': 2.5}",
#     "{'window_size': 136, 'multiplier': 2.0}",
#     "{'window_size': 140, 'multiplier': 2.5}",
#     "{'window_size': 140, 'multiplier': 2.0}"],
#    'short': []},
#   '1000SHIB': {'long': [], 'short': []},
#   'NEAR': {'long': ["{'window_size': 20, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.5}",
#     "{'window_size': 188, 'multiplier': 2.0}",
#     "{'window_size': 188, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 204, 'multiplier': 2.0}",
#     "{'window_size': 204, 'multiplier': 2.5}",
#     "{'window_size': 200, 'multiplier': 2.0}",
#     "{'window_size': 200, 'multiplier': 2.5}",
#     "{'window_size': 196, 'multiplier': 2.5}",
#     "{'window_size': 196, 'multiplier': 2.0}",
#     "{'window_size': 192, 'multiplier': 2.0}",
#     "{'window_size': 192, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 48, 'multiplier': 2.0}",
#     "{'window_size': 48, 'multiplier': 2.5}"]},
#   'STORJ': {'long': [], 'short': []},
#   '1000FLOKI': {'long': [], 'short': []},
#   'MKR': {'long': [],
#    'short': ["{'window_size': 192, 'multiplier': 2.5}",
#     "{'window_size': 192, 'multiplier': 2.0}",
#     "{'window_size': 252, 'multiplier': 2.0}",
#     "{'window_size': 252, 'multiplier': 2.5}",
#     "{'window_size': 220, 'multiplier': 2.5}",
#     "{'window_size': 220, 'multiplier': 2.0}",
#     "{'window_size': 264, 'multiplier': 2.0}",
#     "{'window_size': 264, 'multiplier': 2.5}",
#     "{'window_size': 244, 'multiplier': 2.5}",
#     "{'window_size': 244, 'multiplier': 2.0}",
#     "{'window_size': 256, 'multiplier': 2.0}",
#     "{'window_size': 256, 'multiplier': 2.5}",
#     "{'window_size': 208, 'multiplier': 2.0}",
#     "{'window_size': 208, 'multiplier': 2.5}",
#     "{'window_size': 212, 'multiplier': 2.0}",
#     "{'window_size': 212, 'multiplier': 2.5}",
#     "{'window_size': 272, 'multiplier': 2.5}",
#     "{'window_size': 272, 'multiplier': 2.0}",
#     "{'window_size': 176, 'multiplier': 2.5}",
#     "{'window_size': 176, 'multiplier': 2.0}",
#     "{'window_size': 180, 'multiplier': 2.5}",
#     "{'window_size': 180, 'multiplier': 2.0}",
# ...
#     "{'window_size': 140, 'multiplier': 2.5}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 72, 'multiplier': 2.0}"]},
#   'ATOM': {'long': [],
#    'short': ["{'window_size': 36, 'multiplier': 2.0}",
#     "{'window_size': 36, 'multiplier': 2.5}"]},
#   'ARB': {'long': ["{'window_size': 16, 'multiplier': 2.0}",
#     "{'window_size': 16, 'multiplier': 2.5}",
#     "{'window_size': 64, 'multiplier': 2.0}",
#     "{'window_size': 64, 'multiplier': 2.5}",
#     "{'window_size': 40, 'multiplier': 2.0}",
#     "{'window_size': 40, 'multiplier': 2.5}",
#     "{'window_size': 24, 'multiplier': 2.0}",
#     "{'window_size': 24, 'multiplier': 2.5}",
#     "{'window_size': 56, 'multiplier': 2.0}",
#     "{'window_size': 56, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 88, 'multiplier': 2.5}",
#     "{'window_size': 88, 'multiplier': 2.0}",
#     "{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 52, 'multiplier': 2.0}",
#     "{'window_size': 52, 'multiplier': 2.5}",
#     "{'window_size': 44, 'multiplier': 2.0}",
#     "{'window_size': 44, 'multiplier': 2.5}",
#     "{'window_size': 12, 'multiplier': 2.5}",
#     "{'window_size': 12, 'multiplier': 2.0}",
#     "{'window_size': 60, 'multiplier': 2.0}",
#     "{'window_size': 60, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 232, 'multiplier': 2.5}",
#     "{'window_size': 232, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.5}",
#     "{'window_size': 228, 'multiplier': 2.5}",
#     "{'window_size': 228, 'multiplier': 2.0}",
#     "{'window_size': 180, 'multiplier': 2.5}",
#     "{'window_size': 180, 'multiplier': 2.0}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 16, 'multiplier': 2.0}",
#     "{'window_size': 16, 'multiplier': 2.5}",
#     "{'window_size': 76, 'multiplier': 2.0}",
#     "{'window_size': 76, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.0}"]},
#   'GMT': {'long': ["{'window_size': 28, 'multiplier': 2.0}",
#     "{'window_size': 28, 'multiplier': 2.5}",
#     "{'window_size': 32, 'multiplier': 2.0}",
#     "{'window_size': 32, 'multiplier': 2.5}",
#     "{'window_size': 24, 'multiplier': 2.0}",
#     "{'window_size': 24, 'multiplier': 2.5}"],
#    'short': []},
#   'ETC': {'long': ["{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.0}"],
#    'short': []},
#   'ARK': {'long': [], 'short': []},
#   'BCH': {'long': [], 'short': []},
#   'DOT': {'long': [],
#    'short': ["{'window_size': 20, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.5}"]},
#   '1000PEPE': {'long': [], 'short': []},
#   'LDO': {'long': ["{'window_size': 52, 'multiplier': 2.0}",
#     "{'window_size': 52, 'multiplier': 2.5}",
#     "{'window_size': 120, 'multiplier': 2.5}",
#     "{'window_size': 120, 'multiplier': 2.0}",
#     "{'window_size': 84, 'multiplier': 2.0}",
#     "{'window_size': 84, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 360, 'multiplier': 2.0}",
#     "{'window_size': 360, 'multiplier': 2.5}",
#     "{'window_size': 356, 'multiplier': 2.0}",
#     "{'window_size': 356, 'multiplier': 2.5}",
#     "{'window_size': 188, 'multiplier': 2.5}",
#     "{'window_size': 188, 'multiplier': 2.0}"]},
#   'SUI': {'long': [], 'short': []},
#   'GALA': {'long': [],
#    'short': ["{'window_size': 56, 'multiplier': 2.5}",
#     "{'window_size': 56, 'multiplier': 2.0}"]},
#   'CAKE': {'long': [], 'short': []},
#   'APE': {'long': [], 'short': []},
#   'INJ': {'long': ["{'window_size': 248, 'multiplier': 2.0}",
#     "{'window_size': 248, 'multiplier': 2.5}",
#     "{'window_size': 164, 'multiplier': 2.0}",
#     "{'window_size': 164, 'multiplier': 2.5}",
#     "{'window_size': 244, 'multiplier': 2.0}",
#     "{'window_size': 244, 'multiplier': 2.5}",
#     "{'window_size': 264, 'multiplier': 2.5}",
#     "{'window_size': 264, 'multiplier': 2.0}",
#     "{'window_size': 140, 'multiplier': 2.5}",
#     "{'window_size': 140, 'multiplier': 2.0}",
#     "{'window_size': 156, 'multiplier': 2.0}",
#     "{'window_size': 156, 'multiplier': 2.5}",
#     "{'window_size': 172, 'multiplier': 2.5}",
#     "{'window_size': 172, 'multiplier': 2.0}",
#     "{'window_size': 260, 'multiplier': 2.5}",
#     "{'window_size': 260, 'multiplier': 2.0}",
#     "{'window_size': 128, 'multiplier': 2.0}",
#     "{'window_size': 128, 'multiplier': 2.5}",
#     "{'window_size': 152, 'multiplier': 2.0}",
#     "{'window_size': 152, 'multiplier': 2.5}",
#     "{'window_size': 136, 'multiplier': 2.5}",
#     "{'window_size': 136, 'multiplier': 2.0}",
#     "{'window_size': 148, 'multiplier': 2.5}",
#     "{'window_size': 148, 'multiplier': 2.0}",
#     "{'window_size': 268, 'multiplier': 2.0}",
#     "{'window_size': 268, 'multiplier': 2.5}",
#     "{'window_size': 280, 'multiplier': 2.0}",
#     "{'window_size': 280, 'multiplier': 2.5}",
#     "{'window_size': 284, 'multiplier': 2.0}",
#     "{'window_size': 284, 'multiplier': 2.5}",
#     "{'window_size': 168, 'multiplier': 2.0}",
#     "{'window_size': 168, 'multiplier': 2.5}",
#     "{'window_size': 332, 'multiplier': 2.5}",
#     "{'window_size': 332, 'multiplier': 2.0}",
#     "{'window_size': 212, 'multiplier': 2.5}",
#     "{'window_size': 212, 'multiplier': 2.0}",
#     "{'window_size': 276, 'multiplier': 2.5}",
#     "{'window_size': 276, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.0}",
#     "{'window_size': 236, 'multiplier': 2.5}",
#     "{'window_size': 180, 'multiplier': 2.5}",
#     "{'window_size': 180, 'multiplier': 2.0}",
#     "{'window_size': 144, 'multiplier': 2.0}",
#     "{'window_size': 144, 'multiplier': 2.5}",
#     "{'window_size': 160, 'multiplier': 2.5}",
#     "{'window_size': 160, 'multiplier': 2.0}",
#     "{'window_size': 176, 'multiplier': 2.0}",
#     "{'window_size': 176, 'multiplier': 2.5}",
#     "{'window_size': 272, 'multiplier': 2.5}",
#     "{'window_size': 272, 'multiplier': 2.0}",
#     "{'window_size': 252, 'multiplier': 2.0}",
#     "{'window_size': 252, 'multiplier': 2.5}"],
#    'short': []},
#   'FTM': {'long': [],
#    'short': ["{'window_size': 124, 'multiplier': 2.5}",
#     "{'window_size': 124, 'multiplier': 2.0}",
#     "{'window_size': 148, 'multiplier': 2.5}",
#     "{'window_size': 148, 'multiplier': 2.0}",
#     "{'window_size': 140, 'multiplier': 2.0}",
#     "{'window_size': 140, 'multiplier': 2.5}",
#     "{'window_size': 44, 'multiplier': 2.5}",
#     "{'window_size': 44, 'multiplier': 2.0}"]},
#   'APT': {'long': ["{'window_size': 40, 'multiplier': 2.0}",
#     "{'window_size': 40, 'multiplier': 2.5}",
#     "{'window_size': 20, 'multiplier': 2.0}",
#     "{'window_size': 20, 'multiplier': 2.5}",
#     "{'window_size': 24, 'multiplier': 2.0}",
#     "{'window_size': 24, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 320, 'multiplier': 2.5}",
#     "{'window_size': 320, 'multiplier': 2.0}",
#     "{'window_size': 316, 'multiplier': 2.5}",
#     "{'window_size': 316, 'multiplier': 2.0}",
#     "{'window_size': 324, 'multiplier': 2.0}",
#     "{'window_size': 348, 'multiplier': 2.0}",
#     "{'window_size': 324, 'multiplier': 2.5}",
#     "{'window_size': 348, 'multiplier': 2.5}",
#     "{'window_size': 340, 'multiplier': 2.0}",
#     "{'window_size': 344, 'multiplier': 2.0}",
#     "{'window_size': 344, 'multiplier': 2.5}",
#     "{'window_size': 340, 'multiplier': 2.5}",
#     "{'window_size': 336, 'multiplier': 2.5}",
#     "{'window_size': 336, 'multiplier': 2.0}",
#     "{'window_size': 32, 'multiplier': 2.5}",
#     "{'window_size': 32, 'multiplier': 2.0}",
#     "{'window_size': 328, 'multiplier': 2.0}",
#     "{'window_size': 328, 'multiplier': 2.5}",
#     "{'window_size': 44, 'multiplier': 2.5}",
#     "{'window_size': 44, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}"]},
#   'YFI': {'long': [], 'short': []},
#   'OMG': {'long': [],
#    'short': ["{'window_size': 208, 'multiplier': 2.0}",
#     "{'window_size': 208, 'multiplier': 2.5}",
#     "{'window_size': 212, 'multiplier': 2.0}",
#     "{'window_size': 212, 'multiplier': 2.5}",
#     "{'window_size': 216, 'multiplier': 2.0}",
#     "{'window_size': 216, 'multiplier': 2.5}",
#     "{'window_size': 204, 'multiplier': 2.5}",
#     "{'window_size': 204, 'multiplier': 2.0}",
#     "{'window_size': 224, 'multiplier': 2.5}",
#     "{'window_size': 224, 'multiplier': 2.0}"]},
#   'SEI': {'long': [], 'short': []},
#   'EOS': {'long': [], 'short': []},
#   '1000SHIB': {'long': [], 'short': []},
#   'NEAR': {'long': [], 'short': []},
#   'STORJ': {'long': [], 'short': []},
#   '1000FLOKI': {'long': [], 'short': []},
#   'MKR': {'long': [],
#    'short': ["{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 72, 'multiplier': 2.0}"]},
#   'CYBER': {'long': [], 'short': []},
#   'UNI': {'long': [], 'short': []},
#   'STRAX': {'long': [], 'short': []},
#   'BLUR': {'long': [], 'short': []},
#   'SUSHI': {'long': ["{'window_size': 156, 'multiplier': 2.5}",
#     "{'window_size': 156, 'multiplier': 2.0}",
#     "{'window_size': 152, 'multiplier': 2.0}",
#     "{'window_size': 152, 'multiplier': 2.5}",
#     "{'window_size': 148, 'multiplier': 2.5}",
#     "{'window_size': 148, 'multiplier': 2.0}"],
#    'short': []},
#   'WAVES': {'long': ["{'window_size': 72, 'multiplier': 2.0}",
#     "{'window_size': 72, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 68, 'multiplier': 2.5}",
#     "{'window_size': 68, 'multiplier': 2.0}",
#     "{'window_size': 28, 'multiplier': 2.0}",
#     "{'window_size': 28, 'multiplier': 2.5}"]},
#   'MASK': {'long': [],
#    'short': ["{'window_size': 184, 'multiplier': 2.0}",
#     "{'window_size': 184, 'multiplier': 2.5}"]},
#   'MANA': {'long': [], 'short': []},
#   'EGLD': {'long': [],
#    'short': ["{'window_size': 32, 'multiplier': 2.0}",
#     "{'window_size': 32, 'multiplier': 2.5}"]},
#   'AAVE': {'long': [],
#    'short': ["{'window_size': 232, 'multiplier': 2.0}",
#     "{'window_size': 232, 'multiplier': 2.5}",
#     "{'window_size': 236, 'multiplier': 2.5}",
#     "{'window_size': 236, 'multiplier': 2.0}",
#     "{'window_size': 216, 'multiplier': 2.0}",
#     "{'window_size': 216, 'multiplier': 2.5}",
#     "{'window_size': 188, 'multiplier': 2.0}",
#     "{'window_size': 188, 'multiplier': 2.5}",
#     "{'window_size': 192, 'multiplier': 2.0}",
#     "{'window_size': 192, 'multiplier': 2.5}",
#     "{'window_size': 196, 'multiplier': 2.0}",
#     "{'window_size': 196, 'multiplier': 2.5}",
#     "{'window_size': 200, 'multiplier': 2.0}",
#     "{'window_size': 200, 'multiplier': 2.5}",
#     "{'window_size': 212, 'multiplier': 2.0}",
#     "{'window_size': 212, 'multiplier': 2.5}",
#     "{'window_size': 208, 'multiplier': 2.5}",
#     "{'window_size': 208, 'multiplier': 2.0}",
#     "{'window_size': 204, 'multiplier': 2.5}",
#     "{'window_size': 204, 'multiplier': 2.0}"]},
#   'NEO': {'long': [], 'short': []},
#   'FET': {'long': ["{'window_size': 56, 'multiplier': 2.5}",
#     "{'window_size': 56, 'multiplier': 2.0}",
#     "{'window_size': 52, 'multiplier': 2.0}",
#     "{'window_size': 52, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 24, 'multiplier': 2.0}",
#     "{'window_size': 24, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.5}",
#     "{'window_size': 104, 'multiplier': 2.0}",
#     "{'window_size': 68, 'multiplier': 2.0}",
#     "{'window_size': 68, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 72, 'multiplier': 2.5}",
#     "{'window_size': 72, 'multiplier': 2.0}"],
#    'short': ["{'window_size': 280, 'multiplier': 2.0}",
#     "{'window_size': 280, 'multiplier': 2.5}",
#     "{'window_size': 276, 'multiplier': 2.5}",
#     "{'window_size': 276, 'multiplier': 2.0}",
#     "{'window_size': 272, 'multiplier': 2.0}",
#     "{'window_size': 272, 'multiplier': 2.5}",
#     "{'window_size': 360, 'multiplier': 2.5}",
#     "{'window_size': 344, 'multiplier': 2.5}",
#     "{'window_size': 348, 'multiplier': 2.0}",
#     "{'window_size': 348, 'multiplier': 2.5}",
#     "{'window_size': 352, 'multiplier': 2.0}",
#     "{'window_size': 352, 'multiplier': 2.5}",
#     "{'window_size': 356, 'multiplier': 2.0}",
#     "{'window_size': 356, 'multiplier': 2.5}",
#     "{'window_size': 344, 'multiplier': 2.0}",
#     "{'window_size': 360, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.0}",
#     "{'window_size': 368, 'multiplier': 2.0}",
#     "{'window_size': 368, 'multiplier': 2.5}",
#     "{'window_size': 372, 'multiplier': 2.0}",
#     "{'window_size': 372, 'multiplier': 2.5}",
#     "{'window_size': 376, 'multiplier': 2.0}",
#     "{'window_size': 376, 'multiplier': 2.5}",
#     "{'window_size': 380, 'multiplier': 2.0}",
#     "{'window_size': 364, 'multiplier': 2.5}",
#     "{'window_size': 380, 'multiplier': 2.5}",
#     "{'window_size': 384, 'multiplier': 2.5}",
#     "{'window_size': 384, 'multiplier': 2.0}",
#     "{'window_size': 332, 'multiplier': 2.0}",
#     "{'window_size': 340, 'multiplier': 2.5}",
#     "{'window_size': 332, 'multiplier': 2.5}",
#     "{'window_size': 336, 'multiplier': 2.0}",
#     "{'window_size': 336, 'multiplier': 2.5}",
#     "{'window_size': 340, 'multiplier': 2.0}",
#     "{'window_size': 324, 'multiplier': 2.5}",
#     "{'window_size': 320, 'multiplier': 2.0}",
#     "{'window_size': 328, 'multiplier': 2.5}",
#     "{'window_size': 328, 'multiplier': 2.0}",
#     "{'window_size': 320, 'multiplier': 2.5}",
#     "{'window_size': 324, 'multiplier': 2.0}",
#     "{'window_size': 316, 'multiplier': 2.0}",
#     "{'window_size': 316, 'multiplier': 2.5}"]},
#   'TRX': {'long': [], 'short': []},
#   'GRT': {'long': ["{'window_size': 96, 'multiplier': 2.0}",
#     "{'window_size': 96, 'multiplier': 2.5}",
#     "{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 92, 'multiplier': 2.5}",
#     "{'window_size': 88, 'multiplier': 2.0}",
#     "{'window_size': 88, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 52, 'multiplier': 2.0}",
#     "{'window_size': 52, 'multiplier': 2.5}",
#     "{'window_size': 244, 'multiplier': 2.0}",
#     "{'window_size': 244, 'multiplier': 2.5}",
#     "{'window_size': 12, 'multiplier': 2.0}",
#     "{'window_size': 12, 'multiplier': 2.5}"]},
#   'ALGO': {'long': [], 'short': []},
#   'STX': {'long': ["{'window_size': 104, 'multiplier': 2.0}",
#     "{'window_size': 104, 'multiplier': 2.5}",
#     "{'window_size': 16, 'multiplier': 2.0}",
#     "{'window_size': 16, 'multiplier': 2.5}",
#     "{'window_size': 100, 'multiplier': 2.0}",
#     "{'window_size': 100, 'multiplier': 2.5}",
#     "{'window_size': 12, 'multiplier': 2.0}",
#     "{'window_size': 12, 'multiplier': 2.5}"],
#    'short': ["{'window_size': 208, 'multiplier': 2.5}",
#     "{'window_size': 208, 'multiplier': 2.0}",
#     "{'window_size': 148, 'multiplier': 2.0}",
#     "{'window_size': 148, 'multiplier': 2.5}",
#     "{'window_size': 36, 'multiplier': 2.5}",
#     "{'window_size': 36, 'multiplier': 2.0}",
#     "{'window_size': 144, 'multiplier': 2.0}",
#     "{'window_size': 144, 'multiplier': 2.5}",
#     "{'window_size': 152, 'multiplier': 2.0}",
#     "{'window_size': 152, 'multiplier': 2.5}",
#     "{'window_size': 32, 'multiplier': 2.0}",
#     "{'window_size': 32, 'multiplier': 2.5}",
#     "{'window_size': 28, 'multiplier': 2.0}",
#     "{'window_size': 28, 'multiplier': 2.5}",
#     "{'window_size': 140, 'multiplier': 2.0}",
#     "{'window_size': 140, 'multiplier': 2.5}",
#     "{'window_size': 132, 'multiplier': 2.5}",
#     "{'window_size': 136, 'multiplier': 2.5}",
#     "{'window_size': 132, 'multiplier': 2.0}",
#     "{'window_size': 136, 'multiplier': 2.0}",
#     "{'window_size': 40, 'multiplier': 2.0}",
#     "{'window_size': 40, 'multiplier': 2.5}"]},
#   'XLM': {'long': [],
#    'short': ["{'window_size': 92, 'multiplier': 2.0}",
#     "{'window_size': 92, 'multiplier': 2.5}"]}}}

# %% [markdown]
# ### 樣本外
# 取樣本內前一半參數來看樣本外表現

# %%
df_dict = {}
candidate = ['ETH','BTC','BNB','SOL','MATIC',
               'XRP','DYDX','AVAX','LINK','GAS',
               'DOGE','ORDI','TRB','WLD','ADA',
               'OP','FIL','ZRX','LTC','RUNE','ATOM',
               'ARB','GMT','ETC','ARK','BCH','DOT',
               'LDO','SUI','GALA','CAKE',
               'APE','INJ','FTM','APT','YFI','OMG',
               'SEI','EOS','1000SHIB','NEAR',
               'MKR','CYBER','UNI',
               'BLUR','SUSHI','WAVES','MASK','MANA',
               'EGLD','AAVE','NEO','FET','TRX','GRT','ALGO','STX','XLM']
for coin in candidate:
    df_dict[coin] = pd.read_hdf(f'/Users/johnsonhsiao/Desktop/data/{coin}USDT_PERPETUAL.h5')

# %%
from tqdm.auto import tqdm
start = '2022-01-01'
sep = ''
end = ''

def in_out_test(freq, coin, direction):
        outsample_record = []
        params_df = pd.read_csv(f'/Users/johnsonhsiao/DC_capital_intern/strategy_research/CTA_TEST/Crypto/bband/opt/{freq}/{coin}/{direction}_record_df.csv')
        for idx , row in tqdm(params_df[:int(len(params_df)/2)].iterrows(), total=int(len(params_df)/2), desc="Processing"):
            params = eval(row['params'])
            config = {'freq':freq, 'lag':1, 'fee': 0.0003, 'weekend_filter': False}
            try:
                df = df_dict[coin]
            except:
                df_dict[coin] = pd.read_hdf(f'/Volumes/crypto_data/price_data/binance/1m/{coin}USDT_PERPETUAL.h5')
                df = df_dict[coin]            
            strategy = Strategy(df=df.loc[start:], configs=config)
            analyze = Analyzer(strategy)
            mdd, stat = analyze.outsample_result_gen(params, direction, coin, axv_index=['2023-05-01'])
            params['mdd'] = mdd
            params['sharpe'] = stat['Sharpe Ratio']
            params['calmar'] = stat['Calmar Ratio']
            params['win rate'] = stat['Win Rate [%]']
            outsample_record.append(params)
        max_sharpe = 0
        for i in range(len(outsample_record)):
            if outsample_record[i]['sharpe'] > max_sharpe:
                max_sharpe = outsample_record[i]['sharpe']
                best_params = outsample_record[i]
        if max_sharpe > 1.5:
            print(best_params)
            strategy = Strategy(df=df.loc[start:], configs=config)
            _pf = strategy.strategy(side = direction,params=params)
            analyze = Analyzer(strategy)
            analyze.outsample_result_gen(params, direction, coin, axv_index=['2023-05-01'])

# %%
from tqdm.auto import tqdm
start = '2022-01-01'
sep = ''
end = ''

def outample_params_highland(freq, side, coin):
    outsample_record = []
    params_df = pd.read_csv(f'/Users/johnsonhsiao/DC_capital_intern/strategy_research/CTA_TEST/Crypto/bband/opt/{freq}/{coin}/{direction}_record_df.csv')
    for idx , row in tqdm(params_df[:int(len(params_df)/2)].iterrows(), total=int(len(params_df)/2), desc="Processing"):
        params = eval(row['params'])
        config = {'freq':freq, 'lag':1, 'fee': 0.0003, 'weekend_filter': False}
        df = df_dict[coin]
        strategy = Strategy(df=df.loc[start:], configs=config)
        analyze = Analyzer(strategy)
        mdd, stat = analyze.outsample_result_gen(params, side, coin, axv_index=['2023-05-01'])
        params['mdd'] = mdd
        params['sharpe'] = stat['Sharpe Ratio']
        params['calmar'] = stat['Calmar Ratio']
        params['win rate'] = stat['Win Rate [%]']
        outsample_record.append(params)
    exp = hip.Experiment.from_iterable(outsample_record)
    exp.display()

# %% [markdown]
# ### 挑選參數全樣本結果

# %%
start = '2022-01-01'
sep = ''
end = ''

side = 'both'

params = {'window_l_k': 48, 'window_l_d': 132, 'window_s_k': 52, 'window_s_d': 140}
# sol 1h : 40,48,100,126,95 original
config = {'freq':'1h', 'lag':1, 'fee': 0.0003}
coin = 'ETH'
df = df_dict[coin]
strategy = Strategy(df=df.loc[start:], configs=config)
_pf = strategy.strategy(side = side,params=params)
trades = _pf.trades.records_readable
analyze = Analyzer(strategy)
analyze.show_pf_analysis(params, side, coin, axv_index=['2023-05-01'])
# Out:
# APY: 128.45 %
# MDD: 15.98 %
# MDD Duration 95 days 01:00:00
# worst trade: -10.75 %
# 2022-09-07 04:00:00 ~ 2022-09-09 03:00:00
# avg holding days: 5.29 days
# --------------------------------------------
# PF: 2.64
# Sharpe Ratio: 2.16
# Calmar Ratio: 5.79
# Sortino Ratio: 3.26
# Omega Ratio: 1.10
# --------------------------------------------
# Expectancy : 2.47 %
# Total Time Exposure : 75.38 %
# Total Trades: 97
# Win Rate: 52.58 %
# --------------------------------------------
# PF * Win Rate: 1.385
# (None,
#  Start                               2022-01-01 00:00:00
#  End                                 2023-11-12 23:00:00
#  Period                                681 days 00:00:00
#  Start Value                                     10000.0
#  Min Value                                   9524.910264
#  Max Value                                  34363.056868
#  End Value                                  33929.683914
#  Total Return [%]                             239.296839
#  Benchmark Return [%]                         -44.573538
#  Total Time Exposure [%]                       75.379344
#  Max Gross Exposure [%]                        108.13714
#  Max Drawdown [%]                              15.981857
#  Max Drawdown Duration                  95 days 01:00:00
#  Total Orders                                        185
#  Total Fees Paid                              582.121873
#  Total Trades                                         97
#  Win Rate [%]                                   52.57732
#  Best Trade [%]                                34.982953
#  Worst Trade [%]                              -10.753657
#  Avg Winning Trade [%]                          7.565754
#  Avg Losing Trade [%]                          -3.181502
#  Avg Winning Trade Duration    6 days 09:49:24.705882352
#  Avg Losing Trade Duration     4 days 01:16:57.391304347
#  Profit Factor                                  2.635113
#  Expectancy                                   246.697772
#  Sharpe Ratio                                   2.160517
#  Calmar Ratio                                   5.786359
#  Omega Ratio                                    1.099529
#  Sortino Ratio                                  3.255667
#  dtype: object)
